# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/archive.zip')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
import pandas as pd

# Correct way to read a CSV from a zip file
df = pd.read_csv("/content/archive.zip")

# Display first 5 rows
df.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/archive.zip")
df.tail()
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# ...

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %%
df.shape
# Out:
# (9712, 8)

# %%
df1 = df[["Primary_Device","Gender","Age"]]
df1
# Out:
#      Primary_Device  Gender  Age
# 0        Smartphone    Male   14
# 1            Laptop  Female   11
# 2                TV  Female   18
# 3            Laptop  Female   15
# 4        Smartphone  Female   12
# ...             ...     ...  ...
# 9707     Smartphone    Male   17
# 9708     Smartphone  Female   17
# 9709     Smartphone    Male   16
# 9710             TV    Male   17
# 9711             TV  Female   15
#
# [9712 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Style
sns.set(style="whitegrid")

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_").str.lower()

# Make Urban/Rural column string
df['urban_or_rural'] = df['urban_or_rural'].astype(str)

# --- Gender ---
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="gender", hue="gender", palette="pastel", legend=False)
plt.title("Count of Participants by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.tight_layout()  # Adds spacing
plt.show()

# --- Primary Device ---
plt.figure(figsize=(7,4))
sns.countplot(data=df, x="primary_device", hue="primary_device", palette="muted", legend=False)
plt.title("Count of Participants by Primary Device")
plt.xlabel("Primary Device")
plt.ylabel("Count")
plt.xticks(rotation=30)
plt.tight_layout()  # Adds spacing
plt.show()
# --- Urban or Rural ---
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="urban_or_rural", hue="urban_or_rural", palette="Set2", legend=False)
plt.title("Count of Participants by Location")
plt.xlabel("Location (Urban / Rural)")
plt.ylabel("Count")
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Style
sns.set(style="whitegrid")

# --- Clean column names ---
df.columns = df.columns.str.strip().str.replace(" ", "_").str.lower()
print("Cleaned column names:", df.columns.tolist())
# Output: ['age', 'gender', 'avg_daily_screen_time_hr', ...]

# --- Ensure screen time column is numeric ---
df['avg_daily_screen_time_hr'] = pd.to_numeric(df['avg_daily_screen_time_hr'], errors='coerce')

# Drop NaN values for plotting
df_plot = df.dropna(subset=['avg_daily_screen_time_hr'])

# --- Violin Plot: Screen Time by Gender ---
plt.figure(figsize=(7,5))
sns.violinplot(data=df_plot, x='gender', y='avg_daily_screen_time_hr', palette='pastel')
plt.title('Average Daily Screen Time by Gender')
plt.xlabel('Gender')
plt.ylabel('Screen Time (hours)')
plt.tight_layout()
plt.show()
# --- Violin Plot: Screen Time by Age ---
plt.figure(figsize=(7,5))
sns.violinplot(data=df_plot, x='age', y='avg_daily_screen_time_hr', palette='muted')
plt.title('Average Daily Screen Time by Age')
plt.xlabel('Age')
plt.ylabel('Screen Time (hours)')
plt.tight_layout()
plt.show()
# Out:
# Cleaned column names: ['age', 'gender', 'avg_daily_screen_time_hr', 'primary_device', 'exceeded_recommended_limit', 'educational_to_recreational_ratio', 'health_impacts', 'urban_or_rural']
# /tmp/ipython-input-3961012072.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_plot, x='gender', y='avg_daily_screen_time_hr', palette='pastel')
# /tmp/ipython-input-3961012072.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_plot, x='age', y='avg_daily_screen_time_hr', palette='muted')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv("/content/archive.zip")

# Clean all column names (remove spaces, make lowercase)
df.columns = df.columns.str.strip().str.lower()

# Check columns (optional, just to confirm)
print(df.columns)

# Create a boxplot correctly
sns.boxplot(
    x='gender',
    y='avg_daily_screen_time_hr',
    data=df,
    palette='pastel'
)

plt.title("Gender vs Average Daily Screen Time")
plt.xlabel("Gender")
plt.ylabel("Average Daily Screen Time (hours)")
plt.show()
# Out:
# Index(['age', 'gender', 'avg_daily_screen_time_hr', 'primary_device',
#        'exceeded_recommended_limit', 'educational_to_recreational_ratio',
#        'health_impacts', 'urban_or_rural'],
#       dtype='object')
# /tmp/ipython-input-547839101.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load data
df = pd.read_csv("/content/archive.zip")

# Step 2: Clean column names (important!)
df.columns = df.columns.str.strip().str.lower()

# Step 3: Check column names (optional, just to confirm)
print(df.columns)

# Step 4: Plot histogram
sns.histplot(df['avg_daily_screen_time_hr'], color="green")
plt.title("Distribution of Average Daily Screen Time")
plt.xlabel("Average Daily Screen Time (hours)")
plt.ylabel("Frequency")
plt.show()
# Out:
# Index(['age', 'gender', 'avg_daily_screen_time_hr', 'primary_device',
#        'exceeded_recommended_limit', 'educational_to_recreational_ratio',
#        'health_impacts', 'urban_or_rural'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load dataset
df = pd.read_csv("/content/archive.zip")

# Step 2: Clean column names
df.columns = df.columns.str.strip().str.lower()

# Step 3: Check column names (optional)
print(df.columns)

# Step 4: KDE Plot
sns.kdeplot(df['avg_daily_screen_time_hr'], color="green", fill=True)
plt.title("Distribution of Average Daily Screen Time")
plt.xlabel("Average Daily Screen Time (hours)")
plt.ylabel("Density")
plt.show()
# Out:
# Index(['age', 'gender', 'avg_daily_screen_time_hr', 'primary_device',
#        'exceeded_recommended_limit', 'educational_to_recreational_ratio',
#        'health_impacts', 'urban_or_rural'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load your data
df = pd.read_csv("/content/archive.zip")

# Step 2: Clean the column names
df.columns = df.columns.str.strip().str.lower()

# Step 3: Confirm actual column names
print(df.columns)

# Step 4: Create histogram for Age
sns.histplot(df['age'], color="green", kde=True)
plt.title("Distribution of Age (Years)")
plt.xlabel("Age (Years)")
plt.ylabel("Frequency")
plt.show()
# Out:
# Index(['age', 'gender', 'avg_daily_screen_time_hr', 'primary_device',
#        'exceeded_recommended_limit', 'educational_to_recreational_ratio',
#        'health_impacts', 'urban_or_rural'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -------------------------------------------
# 🧠 Step 1: Example Data (Use your own CSV or df if you already have one)
# -------------------------------------------
# If you already loaded df from CSV, skip this example part.
df = pd.DataFrame({
    'Age': [18, 19, 20, 21, 22, 23, 24, 25,
            18, 19, 20, 21, 22, 23, 24, 25],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female',
               'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male'],
    'Screen_Time': [4, 5, 6, 3, 7, 5, 6, 4, 3, 4, 5, 6, 7, 3, 4, 5]
})

# -------------------------------------------
# 🧩 Step 2: Box Plot — Screen Time by Age
# -------------------------------------------
plt.figure(figsize=(8,5))
sns.boxplot(x='Age', y='Screen_Time', data=df)
plt.title('Screen Time by Age')
plt.xlabel('Age')
plt.ylabel('Average Daily Screen Time (hrs)')
plt.tight_layout()
plt.show()
# -------------------------------------------
# 🧩 Step 3: Box Plot — Screen Time by Gender
# -------------------------------------------
plt.figure(figsize=(6,5))
sns.boxplot(x='Gender', y='Screen_Time', data=df, palette='Set2')
plt.title('Screen Time by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Daily Screen Time (hrs)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3560502770.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='Screen_Time', data=df, palette='Set2')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile

# ✅ Step 1: Read CSV from ZIP file
with zipfile.ZipFile("/content/archive.zip") as z:
    with z.open("Indian_Kids_Screen_Time.csv") as f:
        df = pd.read_csv(f)

# ✅ Step 2: Clean column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# ✅ Step 3: Display few rows
print("✅ Dataset loaded successfully!\n")
print(df.head())

# -------------------------------------------------------------
# 🎨 Step 4: Histogram + KDE for Screen Time
# -------------------------------------------------------------
plt.figure(figsize=(8,5))
sns.histplot(df['avg_daily_screen_time_hr'], kde=True, bins=20, color='skyblue')
plt.title('Distribution of Daily Screen Time (in hours)', fontsize=14)
plt.xlabel('Average Daily Screen Time (hours)')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()
# -------------------------------------------------------------
# 🎨 Step 5: Histogram + KDE for Age
# -------------------------------------------------------------
plt.figure(figsize=(8,5))
sns.histplot(df['age'], kde=True, bins=15, color='lightgreen')
plt.title('Distribution of Age', fontsize=14)
plt.xlabel('Age (years)')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ✅ Dataset loaded successfully!
#
#    age  gender  avg_daily_screen_time_hr primary_device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    exceeded_recommended_limit  educational_to_recreational_ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            health_impacts urban_or_rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'age': [25, 30, 22, 35, 45, 28, 33, 42, 29, 41, 23, 38, 34, 27],
    'gender': ['Male', 'Female', 'Female', 'Male', 'Male', 'Female',
               'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female']
}

df = pd.DataFrame(data)

# KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='age', hue='gender', fill=True, common_norm=False, alpha=0.5)

plt.title('Age Distribution by Gender (KDE Plot)')
plt.xlabel('Age')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'age': [18, 21, 22, 25, 28, 30, 34, 36, 40, 45, 50, 55, 60, 65],
    'screen_time': [7, 8, 6.5, 7.5, 6, 5, 5.5, 4.5, 4, 3.5, 3, 2.5, 2, 1.5]
}

df = pd.DataFrame(data)

# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age', y='screen_time', s=100)

plt.title('Scatter Plot: Age vs Screen Time')
plt.xlabel('Age (years)')
plt.ylabel('Screen Time (hours/day)')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'gender': ['Male', 'Female'],
    'weekday': [5.2, 4.7],
    'weekend': [6.8, 7.1]
}

df = pd.DataFrame(data)

# Reshape to long format
df_melted = df.melt(id_vars='gender',
                    value_vars=['weekday', 'weekend'],
                    var_name='day_type',
                    value_name='screen_time')

# Grouped bar plot
plt.figure(figsize=(8, 6))
sns.barplot(data=df_melted, x='day_type', y='screen_time', hue='gender')

plt.title('Average Screen Time: Weekday vs Weekend by Gender')
plt.xlabel('Day Type')
plt.ylabel('Screen Time (hours/day)')
plt.legend(title='Gender')
plt.grid(True, axis='y')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ----------------------------
# Step 1: Create sample data (or replace with your actual dataset)
# ----------------------------
data = {
    'gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'primary_device': ['Mobile', 'Mobile', 'TV', 'TV', 'Tablet', 'Tablet'],
    'avg_daily_screen_time_hr': [4.2, 3.8, 5.0, 4.6, 3.5, 3.0]
}

df = pd.DataFrame(data)

# ----------------------------
# Step 2: FacetGrid - Screen Time by Device and Gender
# ----------------------------
g = sns.FacetGrid(df, col='gender', height=5, aspect=1)
g.map_dataframe(sns.barplot, x='primary_device', y='avg_daily_screen_time_hr', errorbar=None)

# ----------------------------
# Step 3: Labels & Titles
# ----------------------------
g.set_axis_labels("Primary Device", "Average Daily Screen Time (hours)")
g.set_titles("Gender: {col_name}")

# Rotate x-axis labels
for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-880421649.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# /tmp/ipython-input-880421649.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
# Step 1: Import all libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 2: Load your CSV file
df = pd.read_csv("/content/archive.zip")

# Step 3: Clean column names (optional but avoids small spelling issues)
df.columns = df.columns.str.strip().str.lower()

# Step 4: Create the pairplot (relationship between numerical variables)
sns.pairplot(
    df,
    vars=['age', 'avg_daily_screen_time_hr', 'educational_to_recreational_ratio']
)

# Step 5: Add a title and show the plot
plt.suptitle('Pairplot: Relationships Between Numerical Variables', y=1.02)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/archive.zip")
df.columns = df.columns.str.strip().str.lower()

sns.pairplot(
    df,
    vars=['age', 'avg_daily_screen_time_hr', 'educational_to_recreational_ratio'],
    hue='gender'   # only if gender column exists
)
plt.suptitle('Pairplot: Relationships Between Numerical Variables', y=1.02)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load CSV (ensure file is uploaded or correct path)
df = pd.read_csv("/content/archive.zip")

# Step 2: Clean column names
df.columns = df.columns.str.strip().str.lower()

# Step 3: Select only numerical columns for correlation
numerical_cols = ['age', 'avg_daily_screen_time_hr', 'educational_to_recreational_ratio']

# Step 4: Compute correlation matrix
corr = df[numerical_cols].corr()

# Step 5: Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap: Numerical Variables")
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Create sample data
np.random.seed(0)
n = 500

df = pd.DataFrame({
    'screen_time': np.concatenate([
        np.random.normal(6, 1.5, size=n),  # Simulated screen time for males
        np.random.normal(5, 1.2, size=n)   # Simulated screen time for females
    ]),
    'gender': ['Male'] * n + ['Female'] * n
})

# Plot
sns.histplot(data=df, x='screen_time', hue='gender', kde=True, element='step', stat='density', common_norm=False)
plt.title('Distribution of Screen Time by Gender')
plt.xlabel('Screen Time (hours)')
plt.ylabel('Density')
plt.show()
