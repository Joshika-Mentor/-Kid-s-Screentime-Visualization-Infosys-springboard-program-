# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshika-Mentor/-Kid-s-Screentime-Visualization-Infosys-springboard-program-/blob/Shaik-Anjum/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_path='/content/drive/MyDrive/Colab Notebooks/import pandas as pd'

# %% [markdown]
# The data sample shows that most students, both male and female, exceed the recommended screen time limit, with smartphone and laptop usage being most common; screen time is mainly for recreation rather than education, and several students report health issues like poor sleep and eye strain as a result of their **habits**

# %%
import pandas as pd
df="Indian_Kids_Screen_Time.csv"
df=pd.read_csv(df)
df.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %% [markdown]
# Displaying first five records of our data to see the data format

# %%
df = pd.read_csv('Indian_Kids_Screen_Time.csv')
df.head(3)
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban

# %% [markdown]
# tail() defaultly shows last 5 records

# %%
df.tail()
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# ...

# %% [markdown]
# this function gives info() about our data i.e datatypes of each columns, total non-null values in each columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
It shows the total count of the data

# %%
df.value_counts()
# Out:
# Age  Gender  Avg_Daily_Screen_Time_hr  Primary_Device  Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  Health_Impacts                   Urban_or_Rural
# 18   Male    5.98                      Smartphone      True                        0.49                               Poor Sleep, Eye Strain           Urban             2
# 11   Male    3.86                      TV              True                        0.30                               Poor Sleep                       Urban             2
# 9    Female  4.44                      TV              True                        0.50                               Poor Sleep                       Urban             2
# 11   Female  3.20                      Smartphone      True                        0.35                               Poor Sleep                       Urban             2
# ...

# %% [markdown]
# describe() function gives the statistical measures of the data. By this we can see the count(total number of rows),mean, std, etc. values which gives us some insights about our data

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %% [markdown]
# The dropna() method on the DataFrame df. This method removes rows (or columns, depending on the arguments) that contain missing values (NaN). By default, it removes rows with any missing values.

# %%
df.dropna()
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 4      12  Female                      5.89     Smartphone
# 5      14  Female                      4.88     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %% [markdown]
# fillna() method is missing the value argument, which is required to specify what to fill the missing values with.

# %%
df.fillna(0)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %% [markdown]
# The table shows individual students' ages, genders, and their average daily screen time in hours, revealing that screen time varies widely without a clear pattern based on age or gender.

# %%
df[['Age', 'Gender', 'Avg_Daily_Screen_Time_hr']]
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr
# 0      14    Male                      3.99
# 1      11  Female                      4.61
# 2      18  Female                      3.73
# 3      15  Female                      1.21
# 4      12  Female                      5.89
# ...   ...     ...                       ...
# 9707   17    Male                      3.26
# 9708   17  Female                      4.43
# 9709   16    Male                      5.62
# 9710   17    Male                      5.60
# 9711   15  Female                      6.12
#
# [9712 rows x 3 columns]

# %%
df['Avg_Daily_Screen_Time_hr'].mean()
# Out:
# np.float64(4.3528366968698515)

# %% [markdown]
# "The count plot of Gender shows the distribution of individuals across different gender categories. [Observe the bars and describe the counts for each gender, e.g., 'There is a roughly equal number of male and female participants in the dataset.' or 'There are slightly more [Male/Female] participants than [Female/Male] participants.']"

# %% [markdown]
# The count plot of Primary Device illustrates the frequency of different primary devices used by individuals in the dataset. [Observe the bars and describe the counts for each device, e.g., 'Smartphones are the most frequently used primary device, followed by TVs, Laptops, and Tablets.' or 'The distribution of primary devices shows that [Device Name] is the least common.

# %% [markdown]
# "The count plot of Urban or Rural shows the distribution of individuals based on their location. [Observe the bars and describe the counts for each location, e.g., 'There are significantly more participants from urban areas compared to rural areas.' or 'The number of participants from urban and rural areas is roughly equal.']"

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Gender', palette='pastel')
plt.title('Count of Participants by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(7,4))
sns.countplot(data=df, x='Primary_Device', palette='muted')
plt.title('Count of Participants by Primary Device')
plt.xlabel('Primary Device')
plt.ylabel('Count')
plt.xticks(rotation=30)
plt.show()

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Urban_or_Rural', palette='Set2')
plt.title('Count of Participants by Location')
plt.xlabel('Location (Urban / Rural)')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipython-input-1628756097.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Gender', palette='pastel')
# /tmp/ipython-input-1628756097.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Primary_Device', palette='muted')
# /tmp/ipython-input-1628756097.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Urban_or_Rural', palette='Set2')

# %% [markdown]
# The box plot illustrates the distribution of average daily screen time across different age groups, highlighting the median, quartiles, and potential outliers for each age. [Observe the box plots for each age group and describe any notable patterns, such as changes in the median screen time, the interquartile range (the size of the box), or the presence of outliers as age increases or decreases. For example, 'The median screen time appears to be relatively consistent across most age groups, but there are some outliers, particularly in the [Age Group] range, indicating some individuals in that group have significantly higher screen times than the rest.']"

# %% [markdown]
# "Based on the box plot, the median average daily screen time appears to be [similar/different] between genders. [Mention any notable observations, such as which gender has a higher or lower median, if one gender has a wider range of screen times (larger box), or if there are more outliers in one gender group]. This suggests [a conclusion based on your observation, e.g., 'there is no significant difference in typical screen time between genders,' or 'gender may play a role in the distribution of screen time']."

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='Age', y='Avg_Daily_Screen_Time_hr')
plt.title('Box Plot of Screen Time by Age')
plt.xlabel('Age')
plt.ylabel('Avg_Daily_Screen_Time_hr')
plt.show()

plt.figure(figsize=(6,5))
sns.boxplot(data=df, x='Gender', y='Avg_Daily_Screen_Time_hr', palette='pastel')
plt.title('Box Plot of Screen Time by Gender')
plt.xlabel('Gender')
plt.ylabel('Avg_Daily_Screen_Time_hr')
plt.show()
# Out:
# /tmp/ipython-input-2720780192.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Gender', y='Avg_Daily_Screen_Time_hr', palette='pastel')

# %% [markdown]
# The violin plot illustrates the distribution of average daily screen time for both genders. [Observe the shape of the violin plots and describe any differences in the distributions, e.g., 'Both genders show a similar distribution of screen time, with a peak around [observe peak].' or 'There appears to be a slight difference in the distribution of screen time between genders, with [Gender] having a slightly higher median or wider spread.']"

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='Gender', y='Avg_Daily_Screen_Time_hr')
plt.title('Violin Plot of Average Daily Screen Time by Gender')
plt.show()

# %% [markdown]
# "The violin plot displays the distribution of average daily screen time across different age groups. [Observe the shape of the violin plots for each age group and describe any notable patterns, such as changes in the distribution shape, median screen time, or spread of data as age increases or decreases. For example, 'The distribution of screen time appears to be relatively consistent across most age groups, although there might be slight variations in median screen time or the presence of outliers in certain age ranges.']"

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='Age', y='Avg_Daily_Screen_Time_hr', hue='Age', palette='viridis', legend=False)
plt.title('Violin Plot of Average Daily Screen Time by Age')
plt.show()

# %% [markdown]
# "The histogram illustrates the frequency distribution of average daily screen time among the participants. The shape of the distribution provides insights into the most common screen time durations and the spread of screen time across the dataset."
#
# "Based on the histogram, the distribution of average daily screen time appears to be [describe the shape, e.g., 'roughly symmetrical and bell-shaped (normal)', 'skewed to the right (more individuals with lower screen time)', or 'skewed to the left (more individuals with higher screen time)']. The majority of participants report an average daily screen time around [mention the peak or center of the distribution]. [Mention any other notable features, such as multiple peaks or a wide spread]."

# %%
#histogram  and kde plots for continious varaiables(screen time and age)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(8,5))
sns.histplot(df['Avg_Daily_Screen_Time_hr'], bins=15, kde=True, color='skyblue')
plt.title('Histogram & KDE for Screen Time')
plt.xlabel('Avg_Daily_Screen_Time_hr')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=15, kde=True, color='lightgreen')
plt.title('Histogram & KDE for Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# "The histogram displays the frequency distribution of age among the participants in the dataset. This visualization helps to understand the age range of the individuals surveyed and identify the most common age groups."
#
# "Based on the histogram, the distribution of age appears to be [describe the shape, e.g., 'relatively uniform across the ages surveyed', 'peaked around a certain age group', or 'skewed towards younger/older ages']. The data includes participants ranging from [mention the minimum age] to [mention the maximum age], with the highest concentration of individuals in the [mention the most frequent age range] bracket."

# %% [markdown]
# "The Kernel Density Estimate (KDE) plot provides a smoothed representation of the distribution of age, allowing us to visualize the density of data points across the range of age values."
#
# "Based on the KDE plot, the distribution of age appears to be [describe the shape, e.g., 'relatively uniform across the ages surveyed', 'peaked around a certain age group', or 'skewed towards younger/older ages']. The data includes participants ranging from [mention the minimum age] to [mention the maximum age], with the highest concentration of individuals in the [mention the most frequent age range] bracket. The smoothness of the KDE plot helps to highlight the overall trend in age distribution more clearly than a histogram."

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.kdeplot(data=df, x='Avg_Daily_Screen_Time_hr', fill=True, color='skyblue', ax=axes[0])
axes[0].set_title('KDE Plot of Average Daily Screen Time')
axes[0].set_xlabel('Average Daily Screen Time (hours)')
axes[0].set_ylabel('Density')

sns.kdeplot(data=df, x='Age', fill=True, color='lightgreen', ax=axes[1])
axes[1].set_title('KDE Plot of Age')
axes[1].set_xlabel('Age')
axes[1].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# "This scatter plot visualizes the relationship between age and average daily screen time, with each point representing an individual participant. A regression line is also included to show the general trend in this relationship."
#
# "Based on the scatter plot and the regression line, it appears there is [describe the relationship, e.g., 'a slight positive correlation', 'a slight negative correlation', or 'no clear linear relationship'] between age and average daily screen time. This means that as age [increases/decreases], average daily screen time tends to [increase/decrease/stay relatively the same]. [Mention if the data points are tightly clustered around the line or widely scattered, indicating the strength of the relationship]."

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV data (adjust filename/path as needed)
df = pd.read_csv('Indian_Kids_Screen_Time.csv')

# Scatter plot: Age vs. Avg Daily Screen Time
plt.scatter(df['Age'], df['Avg_Daily_Screen_Time_hr'], alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Avg Daily Screen Time (hr)')
plt.title('Age vs Daily Screen Time')
plt.grid(True)
plt.show()

# %% [markdown]
# This scatter plot visualizes the relationship between age and average daily screen time, with each point representing an individual participant. A regression line is also included to show the general trend in this relationship."
#
# "Based on the scatter plot and the regression line, it appears there is [describe the relationship, e.g., 'a slight positive correlation', 'a slight negative correlation', or 'no clear linear relationship'] between age and average daily screen time. This means that as age [increases/decreases], average daily screen time tends to [increase/decrease/stay relatively the same]. [Mention if the data points are tightly clustered around the line or widely scattered, indicating the strength of the relationship]."

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Age', y='Avg_Daily_Screen_Time_hr', scatter_kws={'alpha':0.5})
plt.title('Scatter Plot of Average Daily Screen Time vs. Age with Regression Line')
plt.xlabel('Age')
plt.ylabel('Average Daily Screen Time (hours)')
plt.show()

# %% [markdown]
# The grouped barplot displays the average daily screen time for different ages, separated by gender, showing that screen time remains relatively consistent across ages for both males and females. Both gender groups exhibit similar trends with only minor differences, and the standard error bars suggest that any variation is small and not statistically significant. This visualization demonstrates that average daily screen time does not vary greatly by age or gender in this dataset, pointing to a uniform pattern of screen use among students regardless of either factor.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Grouped barplot for different ages by gender
sns.barplot(data=df, x='Age', y='Avg_Daily_Screen_Time_hr', hue='Gender', palette='deep')
plt.title("Group barplot for different ages by Gender")
plt.xlabel("Age")
plt.ylabel("Avg Daily Screen Time (hr)")
plt.show()

# %% [markdown]
# "This FacetGrid plot displays the distribution of average daily screen time, separated by both primary device and gender. Each subplot (facet) represents a combination of a primary device and a gender, showing the histogram and KDE of screen time for that specific group. This allows for a detailed comparison of screen time distributions across different device and gender categories. Observe the shape, peak, and spread of the distributions in each subplot to identify patterns and differences, such as which device/gender combinations have higher or lower average screen times or different variations in screen time."

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")
g= sns.FacetGrid(df,col="Primary_Device",row="Gender",margin_titles=True,height=4)
g.map_dataframe(sns.histplot,x="Avg_Daily_Screen_Time_hr",color="teal",kde=True)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("Screen time Distribution by Device and Gender")
plt.show()

# %% [markdown]
# "This pairplot visualizes the relationships between all pairs of numerical variables in the dataset, including 'Age', 'Avg_Daily_Screen_Time_hr', and 'Educational_to_Recreational_Ratio'. Histograms on the diagonal show the distribution of each individual variable, while the scatter plots in the off-diagonal panels show the pairwise relationships between variables."
#
# "Based on the scatter plots, we can observe the relationships between the numerical variables. For example, [describe the relationship between two variables, e.g., 'there appears to be a slight positive correlation between Age and Avg_Daily_Screen_Time_hr']. The histograms provide insights into the distribution of each variable individually. [Mention any interesting observations from the distributions, e.g., 'Age appears to be relatively uniformly distributed, while Avg_Daily_Screen_Time_hr has a roughly normal distribution']."

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pair plot for the three variables
sns.pairplot(df[['Age', 'Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio']])
plt.show()

# %% [markdown]
# "The pairplot visualizes the relationships between age, average daily screen time, and the educational-to-recreational screen time ratio, separated by gender. It shows that both males and females are spread consistently across the variables, with no strong visible clustering by gender. The distributions suggest that while screen time and ratio values do vary, there is no significant skewness or unusual concentration for either gender in any of the variables. Additionally, the scatter and density plots indicate most students, regardless of gender, cluster around particular values for screen time and the ratio, with only a few outliers. Overall, the relationships between these numerical variables appear similar for both genders, reflecting balanced patterns in this dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Indian_Kids_Screen_Time.csv')
df.columns = df.columns.str.strip().str.lower()

sns.pairplot(
    df,
    vars=['age', 'avg_daily_screen_time_hr', 'educational_to_recreational_ratio'],
    hue='gender'   # only if gender column exists
)
plt.suptitle('Pairplot: Relationships Between Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# "This heatmap visualizes the correlation matrix of the numerical variables in the dataset: 'Age', 'Avg_Daily_Screen_Time_hr', and 'Educational_to_Recreational_Ratio'. The color intensity and the values displayed in each cell indicate the strength and direction of the linear relationship between each pair of variables. A value close to 1 indicates a strong positive correlation, a value close to -1 indicates a strong negative correlation, and a value close to 0 indicates a weak or no linear correlation.
#
# "Based on the correlation heatmap, we can observe the strength and direction of the relationships between the numerical variables. For instance, [describe a significant correlation, e.g., 'there appears to be a moderate negative correlation (-0.49) between Age and Educational_to_Recreational_Ratio, suggesting that as age increases, the ratio of educational to recreational screen time tends to decrease']. [Mention any other notable correlations or lack thereof, e.g., 'The correlation between Age and Avg_Daily_Screen_Time_hr is weak (0.12), indicating a limited linear relationship between these two variables']."

# %%
import matplotlib.pyplot as plt
import seaborn as sns
numeric_df = df.select_dtypes(include=['int64', 'float64'])
# Compute correlation matrix
corr = numeric_df.corr()
# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap: Screen Time, Age, etc.", fontsize=14)
plt.show()

# %% [markdown]
# This histogram displays the distribution of average daily screen time for both male and female participants. The different colored areas represent the frequency of screen time for each gender, with a Kernel Density Estimate (KDE) line overlaid to show the smoothed distribution."
#
# "Based on this histogram, [describe the distribution for each gender, e.g., 'Both genders show a similar distribution of screen time, with a peak around [observe peak]'] or [compare the distributions, e.g., 'There appears to be a slight difference in the distribution, with [Gender] having a slightly higher average screen time or a different spread']."

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Indian_Kids_Screen_Time.csv")

sns.histplot(data=df, x="Avg_Daily_Screen_Time_hr", hue="Gender", kde=True, element="step")
plt.title('Distribution of Screen Time by Gender')
plt.xlabel('Average Daily Screen Time (hr)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# "This stacked bar plot visualizes the distribution of primary devices used by participants, segmented by whether they are located in urban or rural areas. Each bar represents a primary device, and the colored segments within each bar show the proportion of users from urban and rural locations for that device."
#
# "Based on this stacked bar plot, [describe the pattern you see, e.g., 'Smartphones are the most common primary device in both urban and rural areas'] and [compare the distribution of urban and rural users across different devices, e.g., 'the proportion of urban users is higher for all device types compared to rural users' or 'there are notable differences in device usage patterns between urban and rural locations for certain devices, such as [Device Name]']. This suggests that [draw a conclusion based on your observations, e.g., 'location plays a role in the type of primary device used']."

# %%
device_location_counts = df.groupby('Primary_Device')['Urban_or_Rural'].value_counts().unstack(fill_value=0)
plt.figure(figsize=(12, 6))
device_location_counts.plot(kind='bar', stacked=True, rot=0, colormap='viridis')
plt.title('Stacked Bar Plot of Primary Devices by Urban or Rural Location')
plt.xlabel('Primary Device')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# "This swarm plot shows the distribution of average daily screen time for each primary device, with individual data points plotted. Unlike a box plot, it doesn't aggregate the data into quartiles but shows every observation, allowing for a clearer view of the density and spread of data points within each category."
#
# "Based on the swarm plot, [describe the distribution for each device, noting where the points are clustered, if there are gaps, or if there are outliers]. [Compare the distributions across devices, e.g., 'Smartphones appear to have a wider spread of screen times compared to Tablets,' or 'The majority of users for all devices fall within a similar range of screen time, but with some notable exceptions']. This plot provides a detailed view of how individual screen times vary across different primary devices."

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.swarmplot(data=df, x='Primary_Device', y='Avg_Daily_Screen_Time_hr')
plt.title('Swarm Plot of Average Daily Screen Time by Primary Device')
plt.xlabel('Primary Device')
plt.ylabel('Average Daily Screen Time (hours)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# "The swarm plot titled "Screen Time Spread by Gender" shows the distribution of average daily screen time (in hours) for two gender groups among Indian kids. Both genders display a similar distribution, with most values concentrated between 4 and 8 hours per day, indicating that the majority of students, regardless of gender, spend a significant amount of time on screens each day. The plot also highlights a few outliers in both groups, where some individuals report screen times extending up to 12 or 13 hours, expanding the overall range. Overall, there is no distinct difference in screen time patterns between the genders, suggesting that interventions or recommendations regarding screen time could be applied similarly for both groups.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your CSV into a DataFrame
df = pd.read_csv("Indian_Kids_Screen_Time.csv")
import warnings
warnings.filterwarnings("ignore")
# Basic swarmplot: Screen time by Gender
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.swarmplot(data=df, x="Gender", y="Avg_Daily_Screen_Time_hr")
plt.title("Screen Time Spread by Gender")
plt.show()

# %%
health_impact_counts = df['Health_Impacts'].value_counts()
print("Unique values and their counts in 'Health_Impacts' column:")
display(health_impact_counts)
# Out:
# Unique values and their counts in 'Health_Impacts' column:
# Health_Impacts
# Poor Sleep                                       2268
# Poor Sleep, Eye Strain                            979
# Eye Strain                                        644
# Poor Sleep, Anxiety                               608
# Poor Sleep, Obesity Risk                          452
# Anxiety                                           385
# Poor Sleep, Eye Strain, Anxiety                   258
# Obesity Risk                                      252
# Poor Sleep, Eye Strain, Obesity Risk              188
# Eye Strain, Anxiety                               135
# Eye Strain, Obesity Risk                          106
# Poor Sleep, Anxiety, Obesity Risk                  78
# Anxiety, Obesity Risk                              69
# Poor Sleep, Eye Strain, Anxiety, Obesity Risk      37
# Eye Strain, Anxiety, Obesity Risk                  35
# Name: count, dtype: int64

# %%
gender_health_crosstab = pd.crosstab(df['Health_Impacts'], df['Gender'])
device_health_crosstab = pd.crosstab(df['Health_Impacts'], df['Primary_Device'])
location_health_crosstab = pd.crosstab(df['Health_Impacts'], df['Urban_or_Rural'])

print("Cross-tabulation of Health_Impacts and Gender:")
display(gender_health_crosstab)

print("\nCross-tabulation of Health_Impacts and Primary_Device:")
display(device_health_crosstab)

print("\nCross-tabulation of Health_Impacts and Urban_or_Rural:")
display(location_health_crosstab)
# Out:
# Cross-tabulation of Health_Impacts and Gender:
# Gender                                         Female  Male
# Health_Impacts
# Anxiety                                           186   199
# Anxiety, Obesity Risk                              35    34
# Eye Strain                                        324   320
# Eye Strain, Anxiety                                68    67
# Eye Strain, Anxiety, Obesity Risk                  16    19
# Eye Strain, Obesity Risk                           53    53
# Obesity Risk                                      103   149
# Poor Sleep                                       1117  1151
# Poor Sleep, Anxiety                               294   314
# Poor Sleep, Anxiety, Obesity Risk                  45    33
# Poor Sleep, Eye Strain                            480   499
# Poor Sleep, Eye Strain, Anxiety                   119   139
# Poor Sleep, Eye Strain, Anxiety, Obesity Risk      20    17
# Poor Sleep, Eye Strain, Obesity Risk               83   105
# ...

# %%
top_health_impacts = df['Health_Impacts'].value_counts().nlargest(5).index.tolist()
df_filtered = df[df['Health_Impacts'].isin(top_health_impacts)]

fig, axes = plt.subplots(3, 1, figsize=(12, 18))

sns.boxplot(data=df_filtered, x='Health_Impacts', y='Age', ax=axes[0], palette='viridis')
axes[0].set_title('Distribution of Age by Top 5 Health Impacts')
axes[0].set_xlabel('Health Impacts')
axes[0].set_ylabel('Age')
axes[0].tick_params(axis='x', rotation=45)

sns.boxplot(data=df_filtered, x='Health_Impacts', y='Avg_Daily_Screen_Time_hr', ax=axes[1], palette='viridis')
axes[1].set_title('Distribution of Average Daily Screen Time by Top 5 Health Impacts')
axes[1].set_xlabel('Health Impacts')
axes[1].set_ylabel('Average Daily Screen Time (hours)')
axes[1].tick_params(axis='x', rotation=45)

sns.boxplot(data=df_filtered, x='Health_Impacts', y='Educational_to_Recreational_Ratio', ax=axes[2], palette='viridis')
axes[2].set_title('Distribution of Educational to Recreational Ratio by Top 5 Health Impacts')
axes[2].set_xlabel('Health Impacts')
axes[2].set_ylabel('Educational to Recreational Ratio')
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2547102290.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_filtered, x='Health_Impacts', y='Age', ax=axes[0], palette='viridis')
# /tmp/ipython-input-2547102290.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_filtered, x='Health_Impacts', y='Avg_Daily_Screen_Time_hr', ax=axes[1], palette='viridis')
# /tmp/ipython-input-2547102290.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
device_location_counts = df.groupby('Primary_Device')['Urban_or_Rural'].value_counts().unstack(fill_value=0)
plt.figure(figsize=(12, 6))
device_location_counts.plot(kind='bar', stacked=True, rot=0, colormap='viridis')
plt.title('Stacked Bar Plot of Primary Devices by Urban or Rural Location')
plt.xlabel('Primary Device')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.stripplot(data=df, x='Primary_Device', y='Avg_Daily_Screen_Time_hr', alpha=0.5)
plt.title('Stripplot of Average Daily Screen Time by Primary Device')
plt.xlabel('Primary Device')
plt.ylabel('Average Daily Screen Time (hours)')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(data=df, x='Primary_Device', y='Avg_Daily_Screen_Time_hr')
plt.title('Swarm Plot of Average Daily Screen Time by Primary Device')
plt.xlabel('Primary Device')
plt.ylabel('Average Daily Screen Time (hours)')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

sns.countplot(data=df, x='Gender', hue='Gender', palette='viridis', legend=False, ax=axes[0])
axes[0].set_title('Count Plot of Gender')
axes[0].set_xlabel('Gender')
axes[0].set_ylabel('Count')

sns.countplot(data=df, x='Primary_Device', hue='Primary_Device', palette='viridis', legend=False, ax=axes[1])
axes[1].set_title('Count Plot of Primary Device')
axes[1].set_xlabel('Primary Device')
axes[1].set_ylabel('Count')
axes[1].tick_params(axis='x', rotation=45)

sns.countplot(data=df, x='Urban_or_Rural', hue='Urban_or_Rural', palette='viridis', legend=False, ax=axes[2])
axes[2].set_title('Count Plot of Urban or Rural')
axes[2].set_xlabel('Urban or Rural')
axes[2].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

g = sns.FacetGrid(df, col='Gender', row='Primary_Device', height=4, aspect=1.2)
g.map(sns.histplot, 'Avg_Daily_Screen_Time_hr', kde=True)
g.fig.suptitle('Distribution of Average Daily Screen Time by Primary Device and Gender', y=1.03)
g.set_axis_labels('Average Daily Screen Time (hours)', 'Frequency')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

sns.boxplot(data=df, x='Gender', y='Avg_Daily_Screen_Time_hr', hue='Gender', palette='viridis', legend=False, ax=axes[0])
axes[0].set_title('Box Plot of Avg Daily Screen Time by Gender')
axes[0].set_xlabel('Gender')
axes[0].set_ylabel('Average Daily Screen Time (hours)')

sns.boxplot(data=df, x='Primary_Device', y='Avg_Daily_Screen_Time_hr', hue='Primary_Device', palette='viridis', legend=False, ax=axes[1])
axes[1].set_title('Box Plot of Avg Daily Screen Time by Primary Device')
axes[1].set_xlabel('Primary Device')
axes[1].set_ylabel('Average Daily Screen Time (hours)')
axes[1].tick_params(axis='x', rotation=45)

sns.boxplot(data=df, x='Urban_or_Rural', y='Avg_Daily_Screen_Time_hr', hue='Urban_or_Rural', palette='viridis', legend=False, ax=axes[2])
axes[2].set_title('Box Plot of Avg Daily Screen Time by Urban or Rural')
axes[2].set_xlabel('Urban or Rural')
axes[2].set_ylabel('Average Daily Screen Time (hours)')

plt.tight_layout()
plt.show()
