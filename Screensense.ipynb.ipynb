# %% [markdown]
# # ***DV ScreenSense***

# %% [markdown]
# # Connecting google drive to colab

# %%
from google.colab import drive
#Imports the Google Drive module to access files stored in your Google Drive from Colab

drive.mount('/content/drive')
#Connects your Google Drive to Colab

import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/DVScreenSense/Indian_Kids_Screen_Time.csv')
#Imports pandas and loads the CSV file from Google Drive into a DataFrame
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **WEEK 1**
# # Task 1: Learn basics and try some basic methods commonly used in data science

# %%
df.head(10)
#Displays the first 10 rows of the DataFrame
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
# 5   14  Female                      4.88     Smartphone
# 6   17    Male                      2.97             TV
# 7   10    Male                      2.74             TV
# 8   14    Male                      4.61         Laptop
# 9   18    Male                      3.24         Tablet
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# ...

# %%
df.tail(10)
#Displays the last 10 rows of the DataFrame
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9702   13    Male                      6.17     Smartphone
# 9703    9    Male                      6.62     Smartphone
# 9704    8  Female                      4.23             TV
# 9705    9  Female                      8.07             TV
# 9706    8    Male                      4.84     Smartphone
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9702                        True                               0.47
# 9703                        True                               0.48
# 9704                        True                               0.51
# ...

# %%
df.describe
# This method is used to get a statistical summary of the DataFrame, including count, mean, std, min, max, and quartiles for numeric columns
# Out:
# <bound method NDFrame.describe of       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df.shape
# This attribute is used to get the number of rows and columns in the DataFrame
# Out:
# (9712, 8)

# %%
df.info
# This method is used to get a concise summary of the DataFrame, including column names, data types, and non-null counts
# Out:
# <bound method DataFrame.info of       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df[2:5]
# This is used to select and display rows from index 2 to 4 (5 is excluded) in the DataFrame
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#         Health_Impacts Urban_or_Rural
# 2           Poor Sleep          Urban
# 3                  NaN          Urban
# 4  Poor Sleep, Anxiety          Urban

# %%
df.isnull()
# This method is used to check for missing (null) values in the DataFrame, returning True where data is missing
# Out:
#         Age  Gender  Avg_Daily_Screen_Time_hr  Primary_Device  \
# 0     False   False                     False           False
# 1     False   False                     False           False
# 2     False   False                     False           False
# 3     False   False                     False           False
# 4     False   False                     False           False
# ...     ...     ...                       ...             ...
# 9707  False   False                     False           False
# 9708  False   False                     False           False
# 9709  False   False                     False           False
# 9710  False   False                     False           False
# 9711  False   False                     False           False
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                          False                              False
# 1                          False                              False
# ...

# %%
df.dropna()
# This method is used to remove all rows that contain missing (null) values from the DataFrame
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 4      12  Female                      5.89     Smartphone
# 5      14  Female                      4.88     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df.fillna(0)
# This method is used to replace all missing (null) values in the DataFrame with 0
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %% [markdown]
# # Task-2: PPT Presentation on Seaborn. Example illustrations

# %%
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
import seaborn as sns # Import the seaborn library for enhanced visualizations
df = sns.load_dataset("tips") # Load a sample dataset named "tips" from seaborn

plt.hist(df["total_bill"], bins=20) # Create a histogram of the 'total_bill' column with 20 bins
plt.title("Matplotlib Histogram") # Set the title of the plot
plt.show() # Display the plot

# %%
sns.histplot(df["total_bill"], bins=20, kde=True) # Create a histogram of the 'total_bill' column with 20 bins and a Kernel Density Estimate
plt.show() # Display the plot
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# Insights: Matplotlib doesn’t have KDE built-in, but you can combine it with Seaborn to plot KDEs easily

# %%
plt.plot([1,2,3], [4,5,6]) # Create a line plot with x-values [1, 2, 3] and y-values [4, 5, 6]
plt.show() # Display the plot

# %% [markdown]
# Line plot using matplotlib(No whitegrid)

# %%
sns.set_style("whitegrid") # Set the style of the plots to have a white grid background
sns.lineplot(x=[1,2,3],y= [4,5,6]) # Create a line plot with specified x and y values using seaborn
plt.show() # Display the plot

# %% [markdown]
# Insights: Unlike matplotlib, Seaborn’s whitegrid style adds a clean white background with subtle grid lines for better readability and visual appeal.

# %%
import numpy as np # Import the numpy library for numerical operations
means = df.groupby("day")["total_bill"].mean() # Calculate the mean of 'total_bill' grouped by 'day'
stds = df.groupby("day")["total_bill"].std() # Calculate the standard deviation of 'total_bill' grouped by 'day'
plt.bar(means.index, means.values, yerr=stds.values) # Create a bar plot using the calculated means and standard deviations as error bars
# Out:
# /tmp/ipython-input-314331100.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   means = df.groupby("day")["total_bill"].mean()
# /tmp/ipython-input-314331100.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stds = df.groupby("day")["total_bill"].std()
# <BarContainer object of 4 artists>

# %% [markdown]
# In case of matplotlib, to compute statistical estimates, we have to manually type the code.

# %%
sns.barplot(x="day", y="total_bill", data=df) # Create a bar plot showing the total bill for each day
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Insights:Unlike matplotlib, Seaborn automatically computes statistical estimates (like mean and confidence intervals) and applies built-in themes, color palettes, and categorical grouping without manual coding.

# %%
plt.figure(figsize=(6,4)) # Create a new figure for the plot with a specified size
sns.regplot(x="total_bill", y="tip", data=df) # Create a regression plot showing the relationship between 'total_bill' and 'tip'
plt.title("Scatter Plot with Regression Line") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: Unlike matplotlib, Seaborn can automatically fit and display a regression line with confidence intervals using `sns.regplot()` or `sns.lmplot()`.

# %%
plt.figure(figsize=(6,4)) # Create a new figure for the plot with a specified size
sns.histplot(df["tip"], kde=True, bins=15) # Create a histogram of the 'tip' column with a Kernel Density Estimate and 15 bins
plt.title("Histogram with KDE (Density Curve)") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: Unlike matplotlib, Seaborn provides a variety of built-in real-world datasets (like tips, iris, and titanic) allowing users to practice and visualize data without needing external files.

# %% [markdown]
# Day-3: Code discussed in class

# %%
print(df.isnull()) # Check for missing (null) values in the DataFrame and print the result
# Out:
#         Age  Gender  Avg_Daily_Screen_Time_hr  Primary_Device  \
# 0     False   False                     False           False
# 1     False   False                     False           False
# 2     False   False                     False           False
# 3     False   False                     False           False
# 4     False   False                     False           False
# ...     ...     ...                       ...             ...
# 9707  False   False                     False           False
# 9708  False   False                     False           False
# 9709  False   False                     False           False
# 9710  False   False                     False           False
# 9711  False   False                     False           False
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                          False                              False
# 1                          False                              False
# ...

# %%
print(df.isnull().sum()) # Calculate the sum of null values for each column and print the result
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
print(df.isnull().sum().sum()) # Calculate the total number of null values in the DataFrame and print the result
# Out:
# 3218

# %%
print(df.dtypes) # Print the data types of each column in the DataFrame
# Out:
# Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
df['Gender']=df['Gender'].astype('category') # Convert the 'Gender' column to the 'category' data type
df['Urban_or_Rural']=df['Urban_or_Rural'].astype('category') # Convert the 'Urban_or_Rural' column to the 'category' data type

# %%
print(df.dtypes)
# Out:
# Age                                     int64
# Gender                               category
# Avg_Daily_Screen_Time_hr              float64
# Primary_Device                         object
# Exceeded_Recommended_Limit               bool
# Educational_to_Recreational_Ratio     float64
# Health_Impacts                         object
# Urban_or_Rural                       category
# dtype: object

# %%
print(df['Gender'].cat.categories) # Print the categories in the 'Gender' column
print(df['Urban_or_Rural'].cat.categories) # Print the categories in the 'Urban_or_Rural' column
# Out:
# Index(['Female', 'Male'], dtype='object')
# Index(['Rural', 'Urban'], dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# # **WEEK 2: Univariate & Bivariate Analysis**

# %% [markdown]
# # Day 1: Histograms& KDE plots for continuous variables(Screen time,age).

# %%
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
import seaborn as sns # Import the seaborn library for enhanced visualizations
plt.figure(figsize=(8,5)) # Create a new figure for the plot with a specified size
sns.histplot(df['Avg_Daily_Screen_Time_hr'],kde=True) # Create a histogram of 'Avg_Daily_Screen_Time_hr' with a KDE curve
plt.title('Distribution of screentime in hours') # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The distribution of daily screentime is left-skewed with a peak around 4.5 to 5.5 hours.

# %%
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
import seaborn as sns # Import the seaborn library for enhanced visualizations
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', kde=True, color='violet')
plt.title('Histplot of Age')
plt.show()

# %% [markdown]
# Insighs: The distribution of Age is approximately uniform across the observed range of 8 to 18 years, meaning there's a roughly equal frequency (around 850 to 900 counts) for each age group.

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

sns.kdeplot(data=df, x='Avg_Daily_Screen_Time_hr', fill=True, color='blue') # Create a KDE plot of 'Avg_Daily_Screen_Time_hr', filling the area and setting the color to blue
plt.title('KDE Plot of Average Daily Screen Time') # Set the title of the plot
plt.xlabel('Average Daily Screen Time (hours)') # Set the label for the x-axis
plt.ylabel('Density') # Set the label for the y-axis
plt.show() # Display the plot

# %% [markdown]
# Insights: The Kernel Density Estimate (KDE) plot shows that the Average Daily Screen Time is unimodal with a strong peak around 5 hours.

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

sns.kdeplot(data=df, x='Age', fill=True, color='orange') # Create a KDE plot of 'Age', filling the area and setting the color to orange
plt.title('KDE Plot of Age') # Set the title of the plot
plt.xlabel('Age') # Set the label for the x-axis
plt.ylabel('Density') # Set the label for the y-axis
plt.show() # Display the plot

# %% [markdown]
# Insights: The Kernel Density Estimate (KDE) plot shows the Age distribution is highly uniform (rectangular-shaped) between approximately 8 and 18 years, indicating a near-equal density of individuals across that range.

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Avg_Daily_Screen_Time_hr', 'Primary_Device',
#        'Exceeded_Recommended_Limit', 'Educational_to_Recreational_Ratio',
#        'Health_Impacts', 'Urban_or_Rural'],
#       dtype='object')

# %% [markdown]
# # Day 2: Countplots for categorial variables(Gender,Device type, Location)

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
sns.countplot(x="Gender", data=df,color="lightgreen") # Create a countplot of the 'Gender' column with lightgreen color
plt.title(" Screen Time Trends by Gender ") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The plot shows a nearly balanced representation of genders, with the number of Male children (approximately 4900) being only slightly higher than the number of Female children (approximately 4800) in the dataset.

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
sns.countplot(x="Urban_or_Rural", data=df,color="hotpink") # Create a countplot of the 'Urban_or_Rural' column with hotpink color
plt.title("Screen Time Distribution Across Locations") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The data shows a significantly higher count of kids in Urban locations (approximately 6900) are having higher screen time compared to those in Rural locations (approximately 2900).

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
sns.countplot(x="Primary_Device", data=df,color="mediumslateblue") # Create a countplot of the 'Primary_Device' column with mediumslateblue color
plt.title("Screen Time by Device Type") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The primary insight into kids' screen time is that the Smartphone is the dominant device used, accounting for over 4500 children, which is nearly twice the number of children whose primary device is a TV (around 2500) or a Laptop/Tablet (both under 1500).

# %% [markdown]
# # Day 3: Violin plots (Screen time by gender,by age group)

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
sns.violinplot(x="Gender",y="Age",data=df,palette="Set3") # Create a violin plot of 'Age' by 'Gender' with a Set3 color palette
plt.title("Age Distribution by Gender") # Set the title of the plot
plt.show() # Display the plot
# Out:
# /tmp/ipython-input-3748630448.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Gender",y="Age",data=df,palette="Set3")

# %% [markdown]
# Insights: The age distribution of children is virtually identical for both Male and Female genders, with the median age being the same (around 13 years) and the overall range extending from approximately 7 to 19 years for both groups.

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
sns.boxplot(x="Gender",y="Age",data=df,palette="Set2") # Create a box plot of 'Age' by 'Gender' with a Set2 color palette
plt.title("Age Distribution by Gender") # Set the title of the plot
plt.show() # Display the plot
# Out:
# /tmp/ipython-input-251474910.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gender",y="Age",data=df,palette="Set2")

# %% [markdown]
# Insights: The box plot confirms that the age distribution is extremely similar for both genders, with both Male and Female children having a median age of approximately 13 years, an interquartile range from 10 to 16 years, and a full range from about 8 to 18 years.

# %% [markdown]
# # Day 4: Boxplots (Screentime by gender,by age group)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x="Gender",y="Avg_Daily_Screen_Time_hr",data=df,palette="muted")
plt.title("Screen time by Gender")
plt.show()
# Out:
# /tmp/ipython-input-1480331764.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gender",y="Avg_Daily_Screen_Time_hr",data=df,palette="muted")

# %% [markdown]
# Insights: The box plot indicates that the average daily screen time for Male children is slightly higher than for Female children, with the median screen time for Males being around 4.7 hours compared to approximately 4.5 hours for Females, although both genders exhibit a similar wide range of screentime and a large number of outliers (kids with very high screentime).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x="Age",y="Avg_Daily_Screen_Time_hr",data=df,palette="muted")
plt.title("Screen time by Age")
plt.show()
# Out:
# /tmp/ipython-input-667700223.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Age",y="Avg_Daily_Screen_Time_hr",data=df,palette="muted")

# %% [markdown]
# Insights: The visualization shows a general downward trend in the median average daily screen time as children's age increases, dropping from approximately 3.8-4.0 hours for the youngest ages (8 to 10) to a stable 4.5-5.0 hours for older ages (11 to 18), with the highest variability and most extreme outliers observed among the 8 to 10-year-olds.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x="Age",y="Avg_Daily_Screen_Time_hr",hue="Gender",data=df,palette="muted")
plt.title("Screen time by Age & Gender")
plt.show()

# %% [markdown]
# Insights: The key insight from the plot is that average daily screen time for both genders decreases with age, with a more noticeable decline after age 10, and while Males generally show slightly higher median screen time than Females, the overall distribution and variability of screen time are very similar across both genders for most age groups.

# %% [markdown]
# # Day 5: Scatterplots(Age vs Screen time)

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

sns.scatterplot(x="Age",y="Avg_Daily_Screen_Time_hr",data=df) # Create a scatterplot of 'Avg_Daily_Screen_Time_hr' vs 'Age' using the DataFrame
plt.title("Screen time by Age ") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The scatter plot illustrates that children aged 8 to 10 years have a much wider range of daily screen time, including the highest maximum screentime (up to 14 hours), compared to older children (11 to 18 years), whose screen time range and maximum values are notably capped and more contained (generally under 8.5 hours).

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
sns.scatterplot(x="Gender",y="Avg_Daily_Screen_Time_hr",data=df) # Create a scatterplot of 'Avg_Daily_Screen_Time_hr' vs 'Gender' using the DataFrame
plt.title("Screen time by Gender ") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The scatter plot indicates that the full range of average daily screen time for children is identical for both Male and Female genders, with both groups showing a spread from 0 to nearly 14 hours.

# %% [markdown]
# **Week 2 insights:**
# 1. Day 1: Histograms & KDE plots (Screen Time & Age)
#
# * The majority of children's screen time is concentrated between 4 and 6 hours (left-skewed distribution).
#
# * The age of the children is highly uniform, with a near-equal number of kids across the full range of 8 to 18 years.
#
# 2. Day 2: Countplots (Gender, Device Type, Location)
#
# * The dataset has a nearly balanced count of Male and Female children.
#
# * The Smartphone is the dominant primary device used by children.
#
# * The sample is heavily skewed towards Urban locations, with more than double the number of Urban children compared to Rural.
#
# 3. Day 3: Boxplots & Violin plots (Screen Time by Gender, by Age Group)
#
# * The age distribution is virtually identical for both Male and Female children (median around 13 years).
#
# * Male children have a slightly higher median screen time (around 4.7 hours) compared to Female children (around 4.5 hours).
#
# * The median screen time shows a slight decrease with age, stabilizing after age 10.
#
# 4. Day 4: Scatterplots (Age vs Screen Time)
#
# * Youngest children (8 to 10 years) show the highest variability and absolute maximum screen times (up to 14 hours).
#
# * The range of screen time narrows significantly for children aged 11 and older.

# %% [markdown]
# ---

# %% [markdown]
# # **WEEK 3: Comparative Analysis**

# %% [markdown]
# # Day 1: Grouped barplots(Diff devices by Gender)

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
sns.barplot(x="Primary_Device",y="Avg_Daily_Screen_Time_hr",hue="Gender",data=df,palette="muted") # Create a bar plot of 'Avg_Daily_Screen_Time_hr' by 'Primary_Device' with 'Gender' as hue and a muted color palette
plt.title("Grouped barplot for different devices by Gender") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The plot reveals that the average daily screen time for children is remarkably consistent across the four primary devices (Smartphone, Laptop, TV, and Tablet), hovering around 4.3 to 4.6 hours, and importantly, there is negligible difference in screen time between Male and Female children for any specific primary device.

# %% [markdown]
# # Day 2: FacetGrid(Screen time by device X gender)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the FacetGrid
g = sns.FacetGrid(df, col="Gender", height=5, aspect=1)

# Map the barplot to the grid (assign hue same as x)
g.map_dataframe(
    sns.barplot,
    x="Primary_Device",
    y="Avg_Daily_Screen_Time_hr",
    hue="Primary_Device",      # assign hue same as x
    palette="Set1",
    legend=False
)

# Set axis labels
g.set_axis_labels("Primary Device", "Average Daily Screen Time (hr)")

# Set titles for each facet
g.set_titles(col_template="{col_name}")

# Add a main title
g.fig.suptitle("Screen Time by Device × Gender", fontsize=14, y=1.05)


# Show the plot
plt.show()

# %% [markdown]
# Insights: The visualization demonstrates that average daily screen time for children is highly consistent across all primary devices and between both genders, consistently remaining around 4.3 to 4.6 hours, with Males having the highest average screen time on Smartphones and Females having the highest on Laptops.

# %% [markdown]
# # Day 3: Pairplot(Relationships between numerical variables)

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

selected_columns = ['Age', 'Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio'] # Define a list of selected columns
sns.pairplot(df[selected_columns + ['Urban_or_Rural']], hue='Urban_or_Rural', diag_kind='kde', palette='coolwarm') # Create a pairplot of the selected columns, with hue based on 'Urban_or_Rural', KDE plots on the diagonal, and a coolwarm color palette
plt.suptitle("Pairplot of Age, Screen Time, and Edu-Recreational Ratio by Region", y=1.02) # Set the super title for the entire figure
plt.show() # Display the plot

# %% [markdown]
# Insights: The most striking insight is that Urban children consistently dedicate a significantly higher proportion of their screen time to educational activities (with a ratio peaking around 0.55-0.60) compared to Rural children (whose ratio peaks lower, around 0.35-0.40), despite the average total daily screen time being similarly distributed for both groups (centered around 4-5 hours).

# %% [markdown]
# ## Day 4: Heatmap(Correlation between screen time,age etc.)

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

corr = df[['Age', 'Avg_Daily_Screen_Time_hr']].corr() # Calculate the correlation matrix for the selected columns

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f") # Create a heatmap of the correlation matrix with annotations, using the 'coolwarm' colormap, and formatting values to two decimal places
plt.title("Correlation between Age and Screen Time") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The heatmap indicates a very weak positive correlation of only 0.12 between a child's Age and their Average Daily Screen Time, suggesting that there is little linear relationship between how old a child is and how much total screen time they have.

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

numeric_columns = ['Age', 'Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio'] # Define a list of numeric column names
corr = df[numeric_columns].corr() # Calculate the correlation matrix for the selected numeric columns

plt.figure(figsize=(6,4)) # Create a new figure for the plot with a specified size
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f") # Create a heatmap of the correlation matrix with annotations, using the 'coolwarm' colormap, and formatting values to two decimal places
plt.title("Correlation Heatmap") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The correlation heatmap shows that the Educational-to-Recreational Ratio has a moderate negative correlation of -0.49 with Age (meaning older kids have a lower educational focus), and only a very weak negative correlation of -0.09 with the Average Daily Screen Time (meaning the total amount of screen time has little impact on the ratio).

# %% [markdown]
# **Week 3 insights:**
#
# 1. Day 1 Distribution plots (Screen Time by Gender)
# * The distribution of screen time is almost identical for both Male and Female children, with both genders peaking around 4.5 to 5 hours of daily screen time.
# 2. Day 2 Stacked Barplots (Device Usage by Location)
# * Smartphones are the dominant primary device in both Urban and Rural areas. However, the total volume of device usage (number of children) is more than double in Urban areas.
# 3. Day 3 Swarmplots/Stripplots (Screen Time Spread)
# * The vast majority of children's screen time is concentrated between 2 and 7.5 hours, showing a tight clustering of usage for most of the population.
# 4. Day 4 Combine Multiple Plots into Subplots
# * The combined view confirms the overall trend: most children watch 4–6 hours of screen time, but younger children (8–10) exhibit the highest extreme screen times (up to 14 hours).

# %% [markdown]
# ---

# %% [markdown]
# # **WEEK 4: Advanced Visualizations**

# %% [markdown]
# # Day 1: Distribution plots with hue(Screen time by Gender)

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

sns.displot(df, x='Avg_Daily_Screen_Time_hr', hue='Gender', kind='kde', fill=True, palette='coolwarm') # Create a displot (distribution plot) of 'Avg_Daily_Screen_Time_hr' with 'Gender' as hue, using a kernel density estimate, filling the areas under the curves, and using the 'coolwarm' color palette
plt.title("Distribution of Average Daily Screen Time by Gender") # Set the title of the plot
plt.show() # Display the plot

# %% [markdown]
# Insights: The kernel density estimate shows that the distribution of average daily screen time for children is almost identical between Male and Female genders, with both distributions being right-skewed and peaking similarly around 4.5 to 5 hours.

# %% [markdown]
# # Day 2: Stacked barplots(Device usage by location)

# %%
import pandas as pd # Import the pandas library for data manipulation
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

# Calculate the counts of Primary_Device for each Urban_or_Rural category
device_location_counts = df.groupby('Urban_or_Rural')['Primary_Device'].value_counts().unstack(fill_value=0) # Group by 'Urban_or_Rural' and count 'Primary_Device', then unstack to get counts by location and device, filling missing values with 0

# Create a stacked barplot using pandas plot method
device_location_counts.plot(kind='bar', stacked=True, figsize=(8, 6), cmap='viridis') # Create a stacked bar plot using the calculated counts, with a specified figure size and colormap

plt.title('Device Usage by Location') # Set the title of the plot
plt.xlabel('Location (Urban or Rural)') # Set the label for the x-axis
plt.ylabel('Number of Users') # Set the label for the y-axis
plt.xticks(rotation=0) # Rotate x-axis labels for better readability
plt.legend(title='Primary Device') # Add a legend to the plot with the title 'Primary Device'
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show() # Display the plot

# %% [markdown]
# Insights: The stacked bar chart reveals that Smartphones are the most frequently used primary device for children in both Urban and Rural locations, but the overall volume of device usage is more than double in Urban areas (nearly 7,000 users) compared to Rural areas (under 3,000 users).

# %% [markdown]
# # Day 3:Swarmplots/Stripplots(Screen time spread)

# %%
import seaborn as sns # Import the seaborn library for enhanced visualizations
import matplotlib.pyplot as plt # Import the matplotlib library for plotting

# Create a swarmplot to visualize the spread of daily screen time
plt.figure(figsize=(10, 6)) # Create a new figure for the plot with a specified size
sns.swarmplot(x=df['Avg_Daily_Screen_Time_hr']) # Create a swarmplot of the 'Avg_Daily_Screen_Time_hr' column
plt.title('Distribution of Average Daily Screen Time') # Set the title of the plot
plt.xlabel('Average Daily Screen Time (hr)') # Set the label for the x-axis
plt.show() # Display the plot
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 69.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Insights: The Kernel Density Estimate (KDE) plot shows that the Average Daily Screen Time is unimodal with a strong peak around 5 hours.
# Insights:

# %% [markdown]
# # Day 4: Combine multiple plots into subplots

# %%
import matplotlib.pyplot as plt # Import the matplotlib library for plotting
import seaborn as sns # Import the seaborn library for enhanced visualizations

# Create a figure with a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Plot 1: Histogram of Average Daily Screen Time
sns.histplot(data=df, x='Avg_Daily_Screen_Time_hr', kde=True, ax=axes[0, 0]) # Create a histogram of 'Avg_Daily_Screen_Time_hr' with a KDE curve on the first subplot
axes[0, 0].set_title('Distribution of Average Daily Screen Time') # Set the title for the first subplot
axes[0, 0].set_xlabel('Average Daily Screen Time (hr)') # Set the x-label for the first subplot

# Plot 2: Boxplot of Average Daily Screen Time by Gender
sns.boxplot(data=df, x='Gender', y='Avg_Daily_Screen_Time_hr', ax=axes[0, 1]) # Create a boxplot of 'Avg_Daily_Screen_Time_hr' by 'Gender' on the second subplot
axes[0, 1].set_title('Average Daily Screen Time by Gender') # Set the title for the second subplot
axes[0, 1].set_xlabel('Gender') # Set the x-label for the second subplot
axes[0, 1].set_ylabel('Average Daily Screen Time (hr)') # Set the y-label for the second subplot

# Plot 3: Countplot of Primary Device
sns.countplot(data=df, x='Primary_Device', ax=axes[1, 0], palette='viridis', hue='Primary_Device', legend=False) # Create a countplot of 'Primary_Device' on the third subplot
axes[1, 0].set_title('Count of Primary Device Usage') # Set the title for the third subplot
axes[1, 0].set_xlabel('Primary Device') # Set the x-label for the third subplot
axes[1, 0].set_ylabel('Count') # Set the y-label for the third subplot
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability

# Plot 4: Scatterplot of Age vs Average Daily Screen Time
sns.scatterplot(data=df, x='Age', y='Avg_Daily_Screen_Time_hr', ax=axes[1, 1], alpha=0.6) # Create a scatterplot of 'Age' vs 'Avg_Daily_Screen_Time_hr' on the fourth subplot
axes[1, 1].set_title('Age vs Average Daily Screen Time') # Set the title for the fourth subplot
axes[1, 1].set_xlabel('Age') # Set the x-label for the fourth subplot
axes[1, 1].set_ylabel('Average Daily Screen Time (hr)') # Set the y-label for the fourth subplot


# Adjust layout to prevent titles/labels from overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Insights:
# * Most children have average daily screen time between 4 and 6 hours.
#
# * The Smartphone is the most used primary device by children.
#
# * Younger children (8-10) have the highest and most varied screen times, with some kids watching up to 14 hours.
#
# * The amount of screen time is nearly the same for Male and Female children.
#
# * Older children spend a smaller proportion of their screen time on educational activities.
#
# * The total amount of screen time has very little connection to a child's age.
#
# * Urban children are much more likely to use their screen time for educational activities than rural children.

# %% [markdown]
# **Week 4 insights:**
# 1. Day 1: Distribution Plots (Screen Time by Gender)
# * The distribution of average daily screen time is nearly identical for both Male and Female children. Both distributions are right-skewed and cluster strongly with a peak around 4.5 to 5 hours of daily screen time.
# 2. Day 2: Stacked Barplots (Device Usage by Location)
# * Smartphones are the most frequently used primary device among children in both Urban and Rural areas. However, the overall number of children reporting device usage is more than double in Urban locations compared to Rural locations.
# 3. Day 3: Swarmplots/Stripplots (Screen Time Spread):
# * The data reveals a very tight concentration of children's screen time for the majority of the population, which falls primarily between 2 and 7.5 hours per day.
# 4. Day 4: Combine Multiple Plots into Subplots (Dashboard Overview)
# * The combined visualization confirms the main findings: most children spend between 4 and 6 hours on screens daily. However, it highlights that younger children (8 to 10 years old) exhibit the highest range of screen time, including the most extreme outliers up to 14 hours.
